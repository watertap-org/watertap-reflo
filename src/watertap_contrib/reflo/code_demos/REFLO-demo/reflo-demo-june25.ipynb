# %%
# Relevant Imports
from IPython.display import Image,HTML
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from watertap_contrib.reflo.analysis.case_studies.KBHDP.KBHDP_ZLD import zld_main

# %% [markdown]
# <h1 style="text-align:center;">Demonstration of WaterTAP-REFLO Framework</h1>

# %% [markdown]
# Contents:
# 1. Introduction to the framework
# 2. Components
# 3. Building water treatment flowsheets
# 4. Optimizing water treatment flowsheets
# 5. Building solar surrogate model using PySAM
# 6. Costing Model - Integration of water-energy models
# 7. Sample analysis

# %% [markdown]
# Framework

# %% [markdown]
# <center><img src="figures/demo_images/Slide1.png" width=1000 height=1000><center>

# %% [markdown]
# <center><img src="figures/demo_images/Slide2.png" width=1000 height=1000><center>

# %% [markdown]
# <center><img src="figures/demo_images/Slide3.png" width=1000 height=1000><center>

# %% [markdown]
# <center><img src="figures/demo_images/Slide4.png" width=1000 height=1000><center>

# %% [markdown]
# WaterTAP REFLO Components

# %%
# Figure of the components

# %% [markdown]
# Building Water Treatment Flowsheet: Workflow

# %%
# Write function to build flowsheet

# %% [markdown]
# Optimize Performance of Water Treatment Train

# %% [markdown]
# Adding Costing to Water Treatment Flowsheet

# %% [markdown]
# Creating a Solar Energy Surrogate

# %%
# %%capture
m = zld_main(
        ro_recovery = 0.8,
        md_water_recovery = 0.78,
        nacl_recovery_price = 0,
        heat_price = 0.00894,
        electricity_price = 0.04989,
        grid_frac_heat = 0.5,
        cost_per_total_aperture_area = 297,
        cost_per_storage_capital = 93,
        cost_per_watt_installed = 1.6
        )
# Out:
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.pump.control_volume.work
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.RO.stage[1].module.feed_side.area
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.RO.stage[1].module.area
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.RO.stage[1].module.width
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.NaCl_cryst_product_translator.properties_out[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.NaCl_cryst_product_translator.properties_out[0.0].flow_mass_phase_comp[Liq,NaCl]
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.NaCl_cryst_product_translator.properties_out[0.0].flow_mass_phase_comp[Sol,NaCl]
# 2025-06-19 17:31:55 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.treatment.NaCl_cryst_product_translator.properties_out[0.0].flow_mass_phase_comp[Vap,H2O]
# 2025-06-19 17:31:55 [INFO] idaes.init.fs.treatment.feed: Initialization Complete.
# 2025-06-19 17:31:55 [INFO] idaes.init.fs.treatment.MCAS_to_TDS_translator.properties_out: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.MCAS_to_TDS_translator: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.feed.properties: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.feed: Initialization Step Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.ec.properties_in: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.ec.properties_treated: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.ec.properties_byproduct: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.ec.properties_in: State Released.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.EC.ec: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.sludge.properties: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.sludge: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.feed.properties: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.feed: Initialization Step Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.unit.properties_in: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.unit.properties_treated: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.unit.properties_byproduct: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.unit.properties_in: State Released.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.unit: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.product.properties: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.product: Initialization Step Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.disposal.properties: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF.disposal: Initialization Step Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF_waste.properties: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.UF_waste: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.TDS_to_NaCl_translator.properties_in: Initialization Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.TDS_to_NaCl_translator.properties_in: State Released.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.TDS_to_NaCl_translator: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.pump.control_volume: Initialization Complete
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.pump: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.RO.feed: Initialization Step Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.RO.stage[1].feed: Initialization Step Complete.
# 2025-06-19 17:31:56 [INFO] idaes.init.fs.treatment.RO.stage[1].module.feed_side: Initialization Complete
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.watertap.core.util.initialization: variable fs.treatment.RO.stage[1].module.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.stage[1].module: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.stage[1].permeate: Initialization Step Complete.
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.stage[1].retentate: Initialization Step Complete.
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.disposal: Initialization Step Complete.
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.primary_mixer: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.product: Initialization Step Complete.
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.treatment.RO.disposal: Initialization Step Complete.
# 2025-06-19 17:31:57 [INFO] idaes.watertap_contrib.reflo.analysis.multiperiod.vagmd_batch.VAGMD_batch_multiperiod_unit_model: For module AS7C1.5L, when the final brine salinity is larger than 175.3 g/L,the operational parameters will be fixed at nominal condition
# 2025-06-19 17:31:57 [WARNING] idaes.apps.grid_integration.multiperiod.multiperiod: model_data_kwargs argument is provided, so the flowsheet options are different for different time instances. In this case, the multiperiod model is returned without initialization.
# 2025-06-19 17:31:57 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: Constructing flowsheet model for time index 0
# 2025-06-19 17:31:57 [INFO] idaes.init.fs.vagmd.cooling_in_props: fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:31:57 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:57 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:57 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:57 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_out_props: fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.feed_props: fs.vagmd.feed_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: Constructing flowsheet model for time index 1
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_in_props: fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_out_props: fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.feed_props: fs.vagmd.feed_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: Constructing flowsheet model for time index 2
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_in_props: fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_out_props: fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.feed_props: fs.vagmd.feed_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: Constructing flowsheet model for time index 3
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_in_props: fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_out_props: fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.feed_props: fs.vagmd.feed_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: Constructing flowsheet model for time index 4
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_in_props: fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_out_props: fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_out_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.feed_props: fs.vagmd.feed_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable conc_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable temperature was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.feed_props[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:31:58 [INFO] idaes.apps.grid_integration.multiperiod.multiperiod: Constructing flowsheet model for time index 5
# 2025-06-19 17:31:58 [INFO] idaes.init.fs.vagmd.cooling_in_props: fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:31:58 [WARNING] idaes.watertap.property_models.seawater_prop_pack: While using the calculate_state method on fs.vagmd.cooling_in_props[0.0], variable flow_vol_phase was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# ...
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd: Starting initialization of avg_cooling_props
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd.avg_cooling_props: blocks[34].process.fs.vagmd.avg_cooling_props State Released.
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd: Starting initialization of cooling_in_props
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd.cooling_in_props: blocks[34].process.fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd: Starting initialization of cooling_out_props
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd.cooling_out_props: blocks[34].process.fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd: Starting initialization of avg_condenser_props
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd.avg_condenser_props: blocks[34].process.fs.vagmd.avg_condenser_props State Released.
# 2025-06-19 17:32:19 [INFO] idaes.init.blocks[34].process.fs.vagmd: Starting initialization of permeate_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[34].process.fs.vagmd.permeate_props: blocks[34].process.fs.vagmd.permeate_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[34].process.fs.vagmd.feed_props: blocks[34].process.fs.vagmd.feed_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[34].process.fs.vagmd: Initialization status optimal - Optimal Solution Found.
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.feed_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.feed_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.permeate_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.permeate_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.evaporator_in_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.evaporator_in_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.evaporator_out_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.evaporator_out_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.condenser_in_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.condenser_in_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.condenser_out_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.condenser_out_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.cooling_in_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.cooling_in_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.cooling_out_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.cooling_out_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.avg_cooling_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.avg_cooling_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.avg_feed_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.avg_feed_props[0.0].flow_mass_phase_comp[Liq,TDS]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.avg_condenser_props[0.0].flow_mass_phase_comp[Liq,H2O]
# 2025-06-19 17:32:20 [WARNING] idaes.core.util.scaling: Missing scaling factor for blocks[35].process.fs.vagmd.avg_condenser_props[0.0].flow_mass_phase_comp[Vap,H2O]
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization...
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Initialization for feed Completed.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of evaporator_in_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.evaporator_in_props: blocks[35].process.fs.vagmd.evaporator_in_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of evaporator_out_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.evaporator_out_props: blocks[35].process.fs.vagmd.evaporator_out_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of condenser_in_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.condenser_in_props: blocks[35].process.fs.vagmd.condenser_in_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of condenser_out_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.condenser_out_props: blocks[35].process.fs.vagmd.condenser_out_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of avg_feed_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.avg_feed_props: blocks[35].process.fs.vagmd.avg_feed_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of avg_cooling_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.avg_cooling_props: blocks[35].process.fs.vagmd.avg_cooling_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of cooling_in_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.cooling_in_props: blocks[35].process.fs.vagmd.cooling_in_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of cooling_out_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.cooling_out_props: blocks[35].process.fs.vagmd.cooling_out_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of avg_condenser_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.avg_condenser_props: blocks[35].process.fs.vagmd.avg_condenser_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Starting initialization of permeate_props
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.permeate_props: blocks[35].process.fs.vagmd.permeate_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd.feed_props: blocks[35].process.fs.vagmd.feed_props State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.blocks[35].process.fs.vagmd: Initialization status optimal - Optimal Solution Found.
# 2025-06-19 17:32:20 [INFO] idaes.init.fs.treatment.md.feed.properties: fs.treatment.md.feed.properties State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.fs.treatment.md.feed: Initialization Step Complete.
# 2025-06-19 17:32:20 [INFO] idaes.init.fs.treatment.sw_to_nacl_disposal.properties_in: fs.treatment.sw_to_nacl_disposal.properties_in State Released.
# 2025-06-19 17:32:20 [INFO] idaes.init.fs.treatment.sw_to_nacl_disposal: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:32:22 [INFO] idaes.init.fs.treatment.mec.unit.effects[1].effect.heating_steam: fs.treatment.mec.unit.effects[1].effect.heating_steam State Released.
# 2025-06-19 17:32:22 [WARNING] idaes.watertap.property_models.water_prop_pack: While using the calculate_state method on fs.treatment.mec.unit.effects[1].effect.heating_steam[0.0], variable flow_mass_phase_comp was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:32:22 [WARNING] idaes.watertap.property_models.water_prop_pack: While using the calculate_state method on fs.treatment.mec.unit.effects[1].effect.heating_steam[0.0], variable pressure was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:32:22 [WARNING] idaes.watertap.property_models.water_prop_pack: While using the calculate_state method on fs.treatment.mec.unit.effects[1].effect.heating_steam[0.0], variable pressure_sat was provided as an argument in var_args, but it does not have a scaling factor. This suggests that the calculate_scaling_factor method has not been used or the variable was created on demand after the scaling factors were calculated. It is recommended to touch all relevant variables (i.e. call them or set an initial value) before using the calculate_scaling_factor method.
# 2025-06-19 17:32:22 [INFO] idaes.init.fs.treatment.mec.unit.effects[1].effect.heating_steam: fs.treatment.mec.unit.effects[1].effect.heating_steam State Released.
# 2025-06-19 17:32:25 [INFO] idaes.init.fs.treatment.sw_to_nacl_product.properties_in: fs.treatment.sw_to_nacl_product.properties_in State Released.
# 2025-06-19 17:32:25 [INFO] idaes.init.fs.treatment.sw_to_nacl_product: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:32:25 [INFO] idaes.init.fs.treatment.product_NaCl_mixer: Initialization Complete: optimal - Optimal Solution Found
# 2025-06-19 17:32:25 [INFO] idaes.init.fs.treatment.product: Initialization Complete.
# 2025-06-19 17:32:25 [WARNING] idaes.core.base.costing_base: flow_expr is an expression with a lower bound of less than zero. Costing requires that all flows have a lower bound equal to or greater than zero to avoid negative costs.
# 2025-06-19 17:32:25 [WARNING] idaes.core.base.costing_base: flow_expr is an expression with a lower bound of less than zero. Costing requires that all flows have a lower bound equal to or greater than zero to avoid negative costs.
# 2025-06-19 17:32:25 [WARNING] idaes.core.base.costing_base: fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd fixed_operating_cost component has a lower bound less than zero. Be aware that this may result in negative costs during optimization.
# 2025-06-19 17:32:25 [WARNING] idaes.core.base.costing_base: flow_expr is an expression with a lower bound of less than zero. Costing requires that all flows have a lower bound equal to or greater than zero to avoid negative costs.
# 2025-06-19 17:32:25 [WARNING] idaes.core.base.costing_base: flow_expr is an expression with a lower bound of less than zero. Costing requires that all flows have a lower bound equal to or greater than zero to avoid negative costs.
# 2025-06-19 17:32:25 [WARNING] idaes.core.base.costing_base: flow_expr is an expression with a lower bound of less than zero. Costing requires that all flows have a lower bound equal to or greater than zero to avoid negative costs.
# 2025-06-19 17:32:25 [WARNING] idaes.watertap.costing.watertap_costing_package: Could not find unique unit for flow fs.treatment.md.unit.overall_elec_power_requirement - (((fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.feed_pump_power_elec + fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.cooling_pump_power_elec)/(0.0010000000000000002*(m**3/l)*fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.module_area*fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.permeate_flux))*(0.04166666666666666*(d/h)*fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.system_capacity))
# 2025-06-19 17:32:25 [WARNING] idaes.watertap.costing.watertap_costing_package: Could not find unique unit for flow fs.treatment.md.unit.overall_thermal_power_requirement - ((fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.thermal_power/(0.0010000000000000002*(m**3/l)*fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.module_area*fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.permeate_flux))*(0.04166666666666666*(d/h)*fs.treatment.md.unit.mp.blocks[35].process.fs.vagmd.system_capacity))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 m = zld_main(
#       2         ro_recovery = 0.8,
#       3         md_water_recovery = 0.78,
#       4         nacl_recovery_price = 0,
#       5         heat_price = 0.00894,
#       6         electricity_price = 0.04989,
#       7         grid_frac_heat = 0.5,
#       8         cost_per_total_aperture_area = 297,
#       9         cost_per_storage_capital = 93,
#      10         cost_per_watt_installed = 1.6
#      11         )
#
# File ~/Documents/watertap-seto/src/watertap_contrib/reflo/analysis/case_studies/KBHDP/KBHDP_ZLD.py:892, in zld_main(Qin, ro_recovery, md_water_recovery, nacl_recovery_price, heat_price, electricity_price, grid_frac_heat, cost_per_total_aperture_area, cost_per_storage_capital, cost_per_watt_installed)
#     889 m.fs.energy = Block()
#     890 m.fs.energy.costing = EnergyCosting()
# --> 892 add_zld_cst(m)
#     893 add_zld_heat_energy_costing(m,cost_per_total_aperture_area,cost_per_storage_capital,heat_price,electricity_price)
#     894 m.fs.energy.cst.unit.heat_load.unfix()
#
# File ~/Documents/watertap-seto/src/watertap_contrib/reflo/analysis/case_studies/KBHDP/KBHDP_ZLD.py:697, in add_zld_cst(m)
#     695 def add_zld_cst(m):
#     696     m.fs.energy.cst = FlowsheetBlock()
# --> 697     build_cst(m.fs.energy.cst)
#     698     set_cst_op_conditions(m.fs.energy.cst, hours_storage=24)
#     699     init_cst(m.fs.energy.cst)
#
# File ~/Documents/watertap-seto/src/watertap_contrib/reflo/analysis/case_studies/KBHDP/components/CST.py:75, in build_cst(blk, __file__)
#      69 dataset_filename = os.path.join(
#      70     os.path.dirname(__file__),
#      71     r"trough_kbhdp_heat_load_1_100_hours_storage_24_T_loop_out_300.pkl",
#      72 )
#      74 # Updating pickle file output column names
# ---> 75 with open(dataset_filename, "rb") as f:
#      76     df = pickle.load(f)
#      78 # Rename the columns
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mhardika/Documents/watertap-seto/src/watertap_contrib/reflo/code_demos/REFLO-demo/src/watertap_contrib/reflo/analysis/case_studies/KBHDP/data/cst/trough_kbhdp_heat_load_1_100_hours_storage_24_T_loop_out_300.pkl'

# %% [markdown]
# #TODO
# 1. K-RPT1 flowsheet
# 2. K-MLD flowsheet
# 3. K-ZLD flowsheet
# 4. Decided analysis-
# 5. Walk through surrogate model development -
